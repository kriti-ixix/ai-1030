# %%
import os 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.image as im

# %% [markdown]
# # Reading the Images

# %%
data_dir = "cell_images"

# %%
os.listdir(data_dir)
# Out:
# ['test', 'train']

# %%
train_path = data_dir + "/train"  
test_path = data_dir + "/test"

# %%
os.listdir(train_path)
# Out:
# ['parasitized', 'uninfected']

# %%
os.listdir(test_path)
# Out:
# ['parasitized', 'uninfected']

# %%
para_cell = train_path + "/parasitized/C68P29N_ThinF_IMG_20150819_134112_cell_153.png"

# %%
para_arr = im.imread(para_cell)

# %%
para_arr.shape
# Out:
# (157, 145, 3)

# %%
plt.imshow(para_arr)

# %%
uninfected_cell = train_path + "/uninfected/C160P121ThinF_IMG_20151116_093109_cell_29.png"

# %%
uninfected_arr = im.imread(uninfected_cell)

# %%
uninfected_arr.shape
# Out:
# (139, 160, 3)

# %%
plt.imshow(uninfected_arr)

# %% [markdown]
# # Checking for dimensions

# %%
dim_1 = []
dim_2 = []

# %%
for image in os.listdir(train_path + "/uninfected"):
    image_path = train_path + "/uninfected/" + image
    img = im.imread(image_path)
    d1, d2, c = img.shape
    dim_1.append(d1)
    dim_2.append(d2)

# %%
for image in os.listdir(train_path + "/parasitized"):
    image_path = train_path + "/parasitized/" + image
    # print(image_path)
    img = im.imread(image_path)
    d1, d2, c = img.shape
    dim_1.append(d1)
    dim_2.append(d2)

# %%
plt.scatter(dim_1, dim_2)

# %% [markdown]
# # Data Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
img_generator=ImageDataGenerator(rotation_range=20,width_shift_range=0.1,rescale=1/255,
                  height_shift_range=0.1,shear_range=0.1,zoom_range=0.1,
                  horizontal_flip=True,fill_mode="nearest")

# %%
plt.imshow(para_arr)

# %%
plt.imshow(img_generator.random_transform(para_arr))

# %% [markdown]
# # Reading the Images

# %%
os.listdir(train_path)
# Out:
# ['parasitized', 'uninfected']

# %%
train_img = []
train_label = []

test_img = []
test_label = []

for folder in os.listdir(train_path):
    for image in os.listdir(train_path + "/" + folder):
        img = im.imread(train_path + "/" + folder + "/" + image)
        train_img.append(img)
        train_label.append(folder)
        
for folder in os.listdir(test_path):
    for image in os.listdir(test_path + "/" + folder):
        img = im.imread(test_path + "/" + folder + "/" + image)
        test_img.append(img)
        test_label.append(folder)

# %%
img_generator.fit()
