# %%
from PIL import Image

# %%
path = "cell_images/train/parasitized/C68P29N_ThinF_IMG_20150819_134112_cell_153.png"

# %%
img = Image.open(path)

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=145x157 at 0x7FF232085700>

# %%
from matplotlib.image import imread

# %%
image_arr = imread(path)

# %%
image_arr.shape
# Out:
# (157, 145, 3)

# %%
input_shape = (128, 128, 3)

# %%
resized_img = img.resize((128, 128))

# %%
resized_img
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FF23210E7C0>

# %%
resized_img.save(path)

# %%
image_arr = imread(path)

# %%
image_arr.shape
# Out:
# (128, 128, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(image_arr)
