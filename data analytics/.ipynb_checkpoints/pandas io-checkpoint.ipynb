# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("HighestGrossers.csv")

# %%
df
# Out:
#     YEAR                                          MOVIE      GENRE  \
# 0   1995                                 Batman Forever      Drama
# 1   1996                               Independence Day  Adventure
# 2   1997                                   Men in Black  Adventure
# 3   1998                                        Titanic  Adventure
# 4   1999            Star Wars Ep. I: The Phantom Menace  Adventure
# 5   2000                 How the Grinch Stole Christmas  Adventure
# 6   2001          Harry Potter and the Sorcerer’s Stone  Adventure
# 7   2002                                     Spider-Man  Adventure
# 8   2003                                   Finding Nemo  Adventure
# 9   2004                                        Shrek 2  Adventure
# 10  2005         Star Wars Ep. III: Revenge of the Sith     Action
# 11  2006     Pirates of the Caribbean: Dead Man’s Chest     Action
# 12  2007                                   Spider-Man 3  Adventure
# ...

# %%
df.set_index("YEAR")
# Out:
#                                               MOVIE      GENRE MPAA RATING  \
# YEAR
# 1995                                 Batman Forever      Drama       PG-13
# 1996                               Independence Day  Adventure       PG-13
# 1997                                   Men in Black  Adventure       PG-13
# 1998                                        Titanic  Adventure       PG-13
# 1999            Star Wars Ep. I: The Phantom Menace  Adventure          PG
# 2000                 How the Grinch Stole Christmas  Adventure          PG
# 2001          Harry Potter and the Sorcerer’s Stone  Adventure          PG
# 2002                                     Spider-Man  Adventure       PG-13
# 2003                                   Finding Nemo  Adventure           G
# 2004                                        Shrek 2  Adventure          PG
# 2005         Star Wars Ep. III: Revenge of the Sith     Action       PG-13
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   YEAR                   27 non-null     int64
#  1   MOVIE                  27 non-null     object
#  2   GENRE                  24 non-null     object
#  3   MPAA RATING            27 non-null     object
#  4   DISTRIBUTOR            27 non-null     object
#  5   TOTAL FOR YEAR         27 non-null     object
#  6   TOTAL IN 2019 DOLLARS  27 non-null     object
#  7   TICKETS SOLD           27 non-null     object
# dtypes: int64(1), object(7)
# memory usage: 1.8+ KB

# %%
df['GENRE'].unique()
# Out:
# array(['Drama', 'Adventure', 'Action', nan], dtype=object)

# %%
df['MPAA RATING'].unique()
# Out:
# array(['PG-13', 'PG', 'G', 'R'], dtype=object)

# %%
df['MPAA RATING'].nunique()
# Out:
# 4

# %%
df[df['MPAA RATING'] == 'R']['MOVIE']
# Out:
# 25    Bad Boys For Life
# Name: MOVIE, dtype: object

# %%
df['DISTRIBUTOR'].value_counts()
# Out:
# Walt Disney           12
# Warner Bros.           4
# Sony Pictures          4
# 20th Century Fox       3
# Paramount Pictures     2
# Universal              1
# Dreamworks SKG         1
# Name: DISTRIBUTOR, dtype: int64
